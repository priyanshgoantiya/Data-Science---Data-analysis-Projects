# %% [markdown]
# ## `Columns Description`
#
# adult: Boolean value indicating if the movie is for adults (True) or not (False).
#
# belongs_to_collection: Information about the collection the movie belongs to (if any).
#
# budget: The budget of the movie in USD.
#
# genres: List of genres associated with the movie.
#
# homepage: URL of the movie's homepage.
#
# id: Unique identifier for the movie.
#
# imdb_id: IMDb identifier for the movie.
#
# original_language: The original language of the movie.
#
# original_title: The original title of the movie.
#
# overview: A brief description or summary of the movie.
#
# popularity: A numeric value representing the popularity of the movie.
#
# poster_path: URL or path to the movie's poster image.
#
# production_companies: List of production companies involved in making
# the movie.
#
# production_countries: List of countries where the movie was produced.
#
# release_date: The release date of the movie.
#
# revenue: The revenue generated by the movie in USD.
#
# runtime: The runtime of the movie in minutes.
#
# spoken_languages: List of languages spoken in the movie.
#
# status: The release status of the movie (e.g., Released, Post Production).
#
# tagline: The tagline or slogan of the movie.
#
# title: The title of the movie.
#
# video: Boolean value indicating if there is a video related to the movie (True) or not (False).
#
# vote_average: The average vote rating of the movie.
#
# vote_count: The total number of votes the movie has received.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth',None)
pd.reset_option('display.max_colwidth')
import json
import ast
import warnings
warnings.filterwarnings("ignore")

# %%
df.shape
# Out:
# (45463, 19)

# %%
df=pd.read_csv('/content/movies_metadata.csv',low_memory=False)
df.head()
# Out:
#    adult  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                                                              belongs_to_collection  \
# 0            {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
# 1                                                                                                                                                              NaN
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}
# 3                                                                                                                                                              NaN
# ...

# %%
df.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                                                             genres  \
# 45461                               [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}]
# 45462                                                                [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]
# 45464                                                                                           []
# 45465                                                                                           []
#
#                                    homepage      id    imdb_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df=df.drop(columns=['homepage','imdb_id','video','adult','original_title'])

# %%
df
# Out:
#                                                                                                                                                  belongs_to_collection  \
# 0                {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
# 1                                                                                                                                                                  NaN
# 2          {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}
# 3                                                                                                                                                                  NaN
# ...

# %%
df['genres'][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
df['belongs_to_collection'][0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %% [markdown]
# ## ALL JSON COLUMNS

# %%
json_col=['belongs_to_collection','genres','production_companies','production_countries','spoken_languages']

# %% [markdown]
# ## CONVERT COLUMNS TO JSON FORMAT

# %%
df['genres'].apply(lambda x:json.loads(x.replace("'",'"')))
# Out:
# 0         [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]
# 2                                         [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 3            [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# 4                                                                           [{'id': 35, 'name': 'Comedy'}]
#                                                        ...
# 45461                                       [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}]
# 45462                                                                        [{'id': 18, 'name': 'Drama'}]
# 45463          [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]
# ...

# %%
df['genres']=df['genres'].apply(ast.literal_eval)

# %%
df['genres']
# Out:
# 0         [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]
# 2                                         [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 3            [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# 4                                                                           [{'id': 35, 'name': 'Comedy'}]
#                                                        ...
# 45461                                       [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}]
# 45462                                                                        [{'id': 18, 'name': 'Drama'}]
# 45463          [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]
# ...

# %% [markdown]
# ## AS IN belongs_to_collection THERE ARE SOME NON-STR VALUES

# %%
df['belongs_to_collection']
# Out:
# 0                  {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
# 1                                                                                                                                                                    NaN
# 2            {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}
# 3                                                                                                                                                                    NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}
#                                                                                       ...
# ...

# %% [markdown]
# ## to check which values is str or not

# %%
df['belongs_to_collection'].apply(lambda x: isinstance(x,str))
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: belongs_to_collection, Length: 45466, dtype: bool

# %%
df['belongs_to_collection']=df['belongs_to_collection'].apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)
df['production_companies']=df['production_companies'].apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)
df['production_countries']=df['production_countries'].apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)
df['spoken_languages']=df['spoken_languages'].apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)

# %%
df.head()
# Out:
#                                                                                                                                              belongs_to_collection  \
# 0            {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
# 1                                                                                                                                                              NaN
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}
# 3                                                                                                                                                              NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}
#
# ...

# %% [markdown]
# ## `how to flatten nested columns`

# %%
df['belongs_to_collection']=df['belongs_to_collection'].apply(lambda x:x['name'] if isinstance(x,dict) else np.nan)

# %%
df.head(10)
# Out:
#             belongs_to_collection    budget  \
# 0            Toy Story Collection  30000000
# 1                             NaN  65000000
# 2       Grumpy Old Men Collection         0
# 3                             NaN  16000000
# 4  Father of the Bride Collection         0
# 5                             NaN  60000000
# 6                             NaN  58000000
# 7                             NaN         0
# 8                             NaN  35000000
# 9           James Bond Collection  58000000
#
#                                                                                                                           genres  \
# 0                               [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]
# 1                              [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]
# ...

# %%
df['genres']=df['genres'].apply(lambda x:'|'.join(i['name'] for i in x))

# %%
df['genres'][0]
# Out:
# 'Animation|Comedy|Family'

# %%
df['genres'].value_counts(dropna=False).head(20)
# Out:
# genres
# Drama                   5000
# Comedy                  3621
# Documentary             2723
#                         2442
# Drama|Romance           1301
# Comedy|Drama            1135
# Horror                   974
# Comedy|Romance           930
# Comedy|Drama|Romance     593
# Drama|Comedy             532
# Horror|Thriller          528
# Drama|Thriller           497
# Thriller                 465
# Crime|Drama              430
# Romance|Drama            343
# Western                  318
# Action|Thriller          301
# Drama|Foreign            283
# Action                   278
# Drama|History            267
# Name: count, dtype: int64

# %%
df['genres']=df['genres'].replace('',np.nan)

# %%
df['spoken_languages']=df['spoken_languages'].apply(lambda x:'|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
df['spoken_languages'].value_counts(dropna=False).head(20)
# Out:
# spoken_languages
# English             22395
#                      3952
# Français             1853
# 日本語                  1289
# Italiano             1218
# Español               902
# Pусский               807
# Deutsch               762
# English|Français      681
# English|Español       572
# हिन्दी                481
# English|Deutsch       462
# 한국어/조선말               425
# 普通话                   347
# English|Italiano      326
# svenska               311
# No Language           303
# suomi                 275
# Português             275
# Polski                213
# Name: count, dtype: int64

# %%
df['spoken_languages']=df['spoken_languages'].replace('',np.nan)

# %%
df['production_countries']=df['production_countries'].apply(lambda x:'|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
df['production_countries']
# Out:
# 0        United States of America
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 4        United States of America
#                    ...
# 45461                        Iran
# 45462                 Philippines
# 45463    United States of America
# 45464                      Russia
# 45465              United Kingdom
# Name: production_countries, Length: 45466, dtype: object

# %%
df['production_countries'].value_counts(dropna=False).head()
# Out:
# production_countries
# United States of America    17851
#                              6282
# United Kingdom               2238
# France                       1654
# Japan                        1356
# Name: count, dtype: int64

# %%
df['production_countries']=df['production_countries'].replace('',np.nan)

# %%
df['production_companies']=df['production_companies'].apply(lambda x:'|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
df['production_companies']
# Out:
# 0                                        Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Communications
# 2                                    Warner Bros.|Lancaster Gate
# 3                         Twentieth Century Fox Film Corporation
# 4                      Sandollar Productions|Touchstone Pictures
#                                   ...
# 45461
# 45462                                                Sine Olivia
# 45463                                    American World Pictures
# 45464                                                  Yermoliev
# 45465
# Name: production_companies, Length: 45466, dtype: object

# %%
df['production_companies'].value_counts(dropna=False).head()
# Out:
# production_companies
#                                           11875
# Metro-Goldwyn-Mayer (MGM)                   742
# Warner Bros.                                540
# Paramount Pictures                          505
# Twentieth Century Fox Film Corporation      439
# Name: count, dtype: int64

# %%
df['production_companies']=df['production_companies'].replace('',np.nan)

# %%
df[df['budget']=='0']
# Out:
#                 belongs_to_collection budget                         genres  \
# 2           Grumpy Old Men Collection      0                 Romance|Comedy
# 4      Father of the Bride Collection      0                         Comedy
# 7                                 NaN      0  Action|Adventure|Drama|Family
# 11                                NaN      0                  Comedy|Horror
# 12                   Balto Collection      0     Family|Animation|Adventure
# ...                               ...    ...                            ...
# 45461                             NaN      0                   Drama|Family
# 45462                             NaN      0                          Drama
# 45463                             NaN      0          Action|Drama|Thriller
# 45464                             NaN      0                            NaN
# 45465                             NaN      0                            NaN
#
#            id original_language  \
# ...

# %% [markdown]
# ## `Clean numeric columns`

# %%
df['budget']=df['budget'].replace(0,np.nan)

# %%
df['budget']=pd.to_numeric(df['budget'],errors='coerce')

# %%
df['budget'].value_counts(dropna=False)
# Out:
# budget
# 0.0           36573
# 5000000.0       286
# 10000000.0      259
# 20000000.0      243
# 2000000.0       242
#               ...
# 9750000.0         1
# 7275000.0         1
# 78146652.0        1
# 280.0             1
# 1254040.0         1
# Name: count, Length: 1224, dtype: int64

# %%
df['budget']=df['budget'].div(1000000)

# %%
df.rename(columns={'budget':'budget(IN MILLIONS)'},inplace=True)

# %%
df.head()
# Out:
#             belongs_to_collection  budget(IN MILLIONS)  \
# 0            Toy Story Collection                 30.0
# 1                             NaN                 65.0
# 2       Grumpy Old Men Collection                  0.0
# 3                             NaN                 16.0
# 4  Father of the Bride Collection                  0.0
#
#                      genres     id original_language  \
# 0   Animation|Comedy|Family    862                en
# 1  Adventure|Fantasy|Family   8844                en
# 2            Romance|Comedy  15602                en
# 3      Comedy|Drama|Romance  31357                en
# 4                    Comedy  11862                en
#
# ...

# %%
df['revenue']=pd.to_numeric(df['revenue'],errors='coerce')

# %%
df['revenue']=df['revenue'].replace(0,np.nan)

# %%
df['revenue']=df['revenue'].div(1000000)

# %%
df.rename(columns={'revenue':'revenue(IN MILLIONS)'},inplace=True)

# %%
df.head()
# Out:
#             belongs_to_collection  budget(IN MILLIONS)  \
# 0            Toy Story Collection                 30.0
# 1                             NaN                 65.0
# 2       Grumpy Old Men Collection                  0.0
# 3                             NaN                 16.0
# 4  Father of the Bride Collection                  0.0
#
#                      genres     id original_language  \
# 0   Animation|Comedy|Family    862                en
# 1  Adventure|Fantasy|Family   8844                en
# 2            Romance|Comedy  15602                en
# 3      Comedy|Drama|Romance  31357                en
# 4                    Comedy  11862                en
#
# ...

# %%
df['runtime'].value_counts(dropna=False)
# Out:
# runtime
# 90.0     2556
# 0.0      1558
# 100.0    1470
# 95.0     1412
# 93.0     1214
#          ...
# 410.0       1
# 283.0       1
# 238.0       1
# 566.0       1
# 780.0       1
# Name: count, Length: 354, dtype: int64

# %%
df['runtime']=df['runtime'].replace(0.0,np.nan)

# %%
df.id.value_counts()
# Out:
# id
# 141971    3
# 168538    2
# 25541     2
# 15028     2
# 11115     2
#          ..
# 72272     1
# 1549      1
# 10171     1
# 38996     1
# 461257    1
# Name: count, Length: 45436, dtype: int64

# %%
df['id']=pd.to_numeric(df['id'],errors='coerce')

# %%
df['id']
# Out:
# 0           862.0
# 1          8844.0
# 2         15602.0
# 3         31357.0
# 4         11862.0
#            ...
# 45461    439050.0
# 45462    111109.0
# 45463     67758.0
# 45464    227506.0
# 45465    461257.0
# Name: id, Length: 45466, dtype: float64

# %%
df['popularity'].value_counts(dropna=False)
# Out:
# popularity
# 0.0         66
# 1e-06       56
# 0.000308    43
# 0.00022     40
# 0.000844    38
#             ..
# 4.762242     1
# 6.173752     1
# 0.645652     1
# 0.556292     1
# 0.163015     1
# Name: count, Length: 43759, dtype: int64

# %%
df['popularity']=pd.to_numeric(df['popularity'],errors='coerce')

# %%
df['popularity'].replace(0.0,np.nan,inplace=True)

# %%
df['vote_count'].value_counts(dropna=False)
# Out:
# vote_count
# 1.0       3264
# 2.0       3132
# 0.0       2899
# 3.0       2787
# 4.0       2480
#           ...
# 2755.0       1
# 1187.0       1
# 4200.0       1
# 3322.0       1
# 2712.0       1
# Name: count, Length: 1821, dtype: int64

# %%
# df['vote_count']=pd.to_numeric(df['vote_count'])

# %%
df['vote_count'].replace(0.0,np.nan,inplace=True)

# %%
df['vote_average'].replace(0.0,np.nan,inplace=True)

# %%
df['vote_average'].value_counts(dropna=False)
# Out:
# vote_average
# NaN    3004
# 6.0    2468
# 5.0    2001
# 7.0    1886
# 6.5    1722
#        ...
# 9.4       3
# 9.6       1
# 9.8       1
# 0.7       1
# 1.1       1
# Name: count, Length: 92, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget(IN MILLIONS)    45463 non-null  float64
#  2   genres                 43024 non-null  object
#  3   id                     45463 non-null  float64
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45394 non-null  float64
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue(IN MILLIONS)   7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
# ...

# %% [markdown]
# ## `Clean datetime column`

# %%
df['release_date']
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45461           NaN
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45466, dtype: object

# %%
df['release_date']=pd.to_datetime(df['release_date'],format='%Y-%m-%d',errors='coerce')

# %%
df['release_date'].value_counts(dropna=False)
# Out:
# release_date
# 2008-01-01    136
# 2009-01-01    121
# 2007-01-01    118
# 2005-01-01    111
# 2006-01-01    101
#              ...
# 1957-09-26      1
# 1938-11-21      1
# 1936-08-19      1
# 2010-01-27      1
# 1917-10-21      1
# Name: count, Length: 17334, dtype: int64

# %%
df.head()
# Out:
#             belongs_to_collection  budget(IN MILLIONS)  \
# 0            Toy Story Collection                 30.0
# 1                             NaN                 65.0
# 2       Grumpy Old Men Collection                  0.0
# 3                             NaN                 16.0
# 4  Father of the Bride Collection                  0.0
#
#                      genres       id original_language  \
# 0   Animation|Comedy|Family    862.0                en
# 1  Adventure|Fantasy|Family   8844.0                en
# 2            Romance|Comedy  15602.0                en
# 3      Comedy|Drama|Romance  31357.0                en
# 4                    Comedy  11862.0                en
#
# ...

# %%
df['original_language'].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, '104.0', 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo',
#        'ay', 'kn', 'eu', 'ne', 'pa', 'ky', 'gl', '68.0', 'uz', 'sm', 'mt',
#        '82.0', 'hy', 'iu', 'lb', 'si'], dtype=object)

# %%
df['original_language'].value_counts(dropna=False)
# Out:
# original_language
# en       32269
# fr        2438
# it        1529
# ja        1350
# de        1080
#          ...
# zu           1
# qu           1
# 104.0        1
# la           1
# si           1
# Name: count, Length: 93, dtype: int64

# %%
x=['82.0','68.0','104.0']
df[df['original_language'].isin(x)]
# Out:
#       belongs_to_collection  budget(IN MILLIONS)  \
# 19730                   NaN                  NaN
# 29503                   NaN                  NaN
# 35587                   NaN                  NaN
#
#                                                                                  genres  \
# 19730   Carousel Productions|Vision View Entertainment|Telescene Film Group Productions
# 29503  Aniplex|GoHands|BROSTA TV|Mardock Scramble Production Committee|Sentai Filmworks
# 35587                           Odyssey Media|Pulser Productions|Rogue State|The Cartel
#
#        id original_language  overview  popularity  \
# 19730 NaN             104.0  Released         NaN
# 29503 NaN              68.0  Released         NaN
# 35587 NaN              82.0  Released         NaN
#
#                                poster_path production_companies  \
# 19730                         Midnight Man                  NaN
# 29503  Mardock Scramble: The Third Exhaust                  NaN
# ...

# %%
df=df[~df['original_language'].isin(x)]

# %%
df['title']
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45461                         Subdue
# 45462            Century of Birthing
# 45463                       Betrayal
# 45464               Satan Triumphant
# 45465                       Queerama
# Name: title, Length: 45463, dtype: object

# %%
df['title'].value_counts(dropna=False)
# Out:
# title
# Cinderella              11
# Hamlet                   9
# Alice in Wonderland      9
# Les Misérables           8
# Beauty and the Beast     8
#                         ..
# Cluny Brown              1
# Babies                   1
# The Green Room           1
# Captain Conan            1
# Queerama                 1
# Name: count, Length: 42278, dtype: int64

# %%
df.head()
# Out:
#             belongs_to_collection  budget(IN MILLIONS)  \
# 0            Toy Story Collection                 30.0
# 1                             NaN                 65.0
# 2       Grumpy Old Men Collection                  0.0
# 3                             NaN                 16.0
# 4  Father of the Bride Collection                  0.0
#
#                      genres       id original_language  \
# 0   Animation|Comedy|Family    862.0                en
# 1  Adventure|Fantasy|Family   8844.0                en
# 2            Romance|Comedy  15602.0                en
# 3      Comedy|Drama|Romance  31357.0                en
# 4                    Comedy  11862.0                en
#
# ...

# %%
df['overview'].value_counts(dropna=False).head(50)
# Out:
# overview
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1104
# ...

# %%
df['overview']=df['overview'].replace('No overview found.',np.nan)
# Out:
# <ipython-input-179-543df72587ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overview']=df['overview'].replace('No overview found.',np.nan)

# %%
df['overview']=df['overview'].replace('No Overview',np.nan)
# Out:
# <ipython-input-175-684d004971f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overview']=df['overview'].replace('No Overview',np.nan)

# %%
df['overview']=df['overview'].replace('No movie overview available.',np.nan)
# Out:
# <ipython-input-176-6e5e7ec927e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overview']=df['overview'].replace('No movie overview available.',np.nan)

# %%
df['overview']=df['overview'].replace(' ',np.nan)
# Out:
# <ipython-input-186-118fe0cd30ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overview']=df['overview'].replace(' ',np.nan)

# %%
df['overview']=df['overview'].replace('No overview yet.',np.nan)
# Out:
# <ipython-input-185-31a875496442>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overview']=df['overview'].replace('No overview yet.',np.nan)

# %%
df['tagline'].value_counts(dropna=False).head(20)
# Out:
# tagline
# NaN                                                           25055
# Based on a true story.                                            7
# Trust no one.                                                     4
# Be careful what you wish for.                                     4
# Who is John Galt?                                                 3
# Some doors should never be opened.                                3
# Drama                                                             3
# Documentary                                                       3
# There is no turning back                                          3
# The end is near.                                                  3
# Classic Albums                                                    3
# Which one is the first to return - memory or the murderer?        3
# How far would you go?                                             3
# Know Your Enemy                                                   3
# ...

# %%
df['tagline']=df['tagline'].replace('-',np.nan)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated(subset='id',keep=False)].sort_values('id')
# Out:
# Empty DataFrame
# Columns: [belongs_to_collection, budget(IN MILLIONS), genres, id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue(IN MILLIONS), runtime, spoken_languages, status, tagline, title, vote_average, vote_count]
# Index: []

# %%
df.drop_duplicates(subset='id',inplace=True)

# %%
df.id.value_counts(dropna=False)
# Out:
# id
# 862.0       1
# 40777.0     1
# 107308.0    1
# 16247.0     1
# 99904.0     1
#            ..
# 44399.0     1
# 10138.0     1
# 32084.0     1
# 42191.0     1
# 461257.0    1
# Name: count, Length: 45433, dtype: int64

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40945
# budget(IN MILLIONS)          0
# genres                    2442
# id                           0
# original_language           11
# overview                  1104
# popularity                  69
# poster_path                386
# production_companies     11871
# production_countries      6282
# release_date                87
# revenue(IN MILLIONS)     38035
# runtime                   1818
# spoken_languages          3953
# status                      84
# tagline                  25036
# title                        3
# vote_average              2998
# vote_count                2899
# dtype: int64

# %%
df[df['title'].isna()]
# Out:
# Empty DataFrame
# Columns: [belongs_to_collection, budget(IN MILLIONS), genres, id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue(IN MILLIONS), runtime, spoken_languages, status, tagline, title, vote_average, vote_count]
# Index: []

# %%
df.dropna(subset='title',inplace=True)

# %%
df['id']=df['id'].astype(int)

# %%
df.notna().sum(axis=1).value_counts().sort_values(ascending=False)
# Out:
# 16    13026
# 17    12500
# 18     5670
# 15     5373
# 14     3279
# 13     1959
# 19     1295
# 12     1100
# 11      598
# 10      368
# 9       132
# 8        98
# 7        19
# 6        11
# 5         2
# Name: count, dtype: int64

# %%
df=df[~(df.notna().sum(axis=1)==6) | (df.notna().sum(axis=1)==5)]

# %% [markdown]
# ## `There is in additional feature in dropna`

# %%
df.dropna(thresh=10,inplace=True)

# %%
df.head()
# Out:
#             belongs_to_collection  budget(IN MILLIONS)  \
# 0            Toy Story Collection                 30.0
# 1                             NaN                 65.0
# 2       Grumpy Old Men Collection                  0.0
# 3                             NaN                 16.0
# 4  Father of the Bride Collection                  0.0
#
#                      genres     id original_language  \
# 0   Animation|Comedy|Family    862                en
# 1  Adventure|Fantasy|Family   8844                en
# 2            Romance|Comedy  15602                en
# 3      Comedy|Drama|Romance  31357                en
# 4                    Comedy  11862                en
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# ...

# %%
df['status'].value_counts()
# Out:
# status
# Released           44739
# Rumored              227
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: count, dtype: int64

# %%
df=df.loc[df['status']=='Released'].copy()

# %%
df.drop(columns='status',inplace=True)

# %%
col=["id", "title", "tagline", "release_date", "genres", "belongs_to_collection",
"original_language", "budget(IN MILLIONS)", "revenue(IN MILLIONS)", "production_companies",
"production_countries", "vote_count", "vote_average", "popularity", "runtime",
"overview", "spoken_languages", "poster_path"]

# %%
df=df.loc[:,col]

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...
