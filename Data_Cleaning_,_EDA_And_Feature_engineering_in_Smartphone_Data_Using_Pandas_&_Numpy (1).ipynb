# %% [markdown]
# ## ` the descriptions for the attributes of a smartphone dataset:`
#
# model: The specific name or identifier of the smartphone model.
#
# price: The cost of the smartphone, typically represented in a currency like USD.
#
# rating: The user or expert rating of the smartphone, usually on a scale (e.g., 1-5 stars).
#
# sim: Indicates the number of SIM card slots or the type of SIM card supported (e.g., Dual SIM, Nano SIM).
#
# processor: The type or model of the processor (CPU) in the smartphone (e.g., Qualcomm Snapdragon 888, Apple A14 Bionic).
#
# ram: The amount of Random Access Memory (RAM) in the smartphone, typically measured in GB (e.g., 4GB, 8GB).
#
# battery: The battery capacity of the smartphone, usually measured in mAh (e.g., 4500mAh).
#
# display: The size and resolution of the smartphone’s screen (e.g., 6.5" AMOLED, 1080x2400 pixels).
#
# camera: The specifications of the smartphone's camera, including resolution and type (e.g., 108MP triple camera, 12MP front camera).
#
# card: The type of memory card slot available, if any (e.g., microSD, up to 1TB).
#
# os: The operating system installed on the smartphone (e.g., Android 11, iOS 14).

# %% [markdown]
# ![](https://www.google.com/imgres?q=smartphone%20dataset&imgurl=https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-datasets-images%2F3668064%2F6366978%2Facd11db746d26ecf81ee7fd1af1f5f11%2Fdataset-card.png%3Ft%3D2023-08-26-07-11-19&imgrefurl=https%3A%2F%2Fwww.kaggle.com%2Fdatasets%2Fabdurrahman22224%2Fsmartphone-new-data&docid=iMzywKdalMJIlM&tbnid=bcT1bPiK4bqAmM&vet=12ahUKEwjy4bDwuuWHAxVmxjgGHWlmMHcQM3oECGMQAA..i&w=1200&h=1200&hcb=2&ved=2ahUKEwjy4bDwuuWHAxVmxjgGHWlmMHcQM3oECGMQAA)

# %% [markdown]
# ![Smartphone](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F13571604%2Fb608498b1cf7f70b9a22952566197db6%2FScreenshot%202023-08-02%20003740.png?generation=1690961033930490&alt=media)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/smartphones - smartphones.csv')
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
df.tail()
# Out:
#                                 model    price  rating  \
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                       sim  \
# 1015                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster
# 1018              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                            processor  \
# 1015   Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016  Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017   Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018    Snapdragon 695, Octa Core, 2.2 GHz Processor
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %% [markdown]
# ## `Data Assessing`

# %% [markdown]
# ## `issue with data`
# quality_issues --->
#
#     "model": "some brands are written differently like OPPO in the model column (consistency)",
#
#     "price": [
#
#         "has unnecessary '₹' (validity)",
#
#         "has ',' between numbers (validity)",
#
#         "phone Namotel has a price of 99 (accuracy)"
#
#     ],
#
#     "ratings": "missing values (completeness)",
#
#     "processor": "has some incorrect values for some Samsung phones (row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) (validity)",
#
#     "ipod": "There is an iPod on row 756 (validity)",
#
#     "memory": "incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) (validity)",
#
#     "battery": "incorrect values in rows (113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) (validity)",
#
#     "display": [
#
#         "sometimes frequency is not available (completeness)",
#
#         "incorrect values in rows (378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) (validity)"
#
#     ],
#
#     "foldable_phones": "certain phones are foldable and the info is scattered (validity)",
#
#     "camera": [
#
#         "words like Dual, Triple, and Quad are used to represent the number of cameras, and front and rear cameras are separated by '&'",
#
#         "problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016) (validity)"
#
#     ],
#
#     "card": "sometimes contains info about os and camera (validity)",
#
#     "os": [
#
#         "sometimes contains info about Bluetooth and FM radio (validity)",
#
#         "issue with rows (324,378) (validity)",
#
#         "sometimes contains os version name like lollipop (consistency)"
#
#     ],
#
#     "missing_values": "missing values in camera, card, and os (completeness)",
#
#     "datatype_issues": "datatype of price and rating is incorrect (validity)"
#
#
# tidiness_issues--->
#
#     "sim": "can be split into 3 columns: has_5g, has_NFC, has_IR_Blaster",
#
#     "ram": "can be split into 2 columns: RAM and ROM",
#
#     "processor": "can be split into processor name, cores, and CPU speed",
#
#     "battery": "can be split into battery capacity and fast_charging_available",
#
#     "display": "can be split into size, resolution_width, resolution_height, and frequency",
#
#     "camera": "can be split into front and rear camera",
#
#     "card": "can be split into supported and extended_upto"

# %% [markdown]
# ## `order of severity`
# 1.> `completeness>valididty>accuracy>consistency`
#
# - `check- you should handle messy data after handeling completeness issue.`

# %% [markdown]
# #### `No duplicate Values in data`

# %%
df1=df.copy()

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1['price']=df1['price'].str.replace('₹','').str.replace(',','').astype(int)

# %%
df1['price']
# Out:
# 0       54999
# 1       19989
# 2       16499
# 3       14999
# 4       24999
#         ...
# 1015    34990
# 1016    14990
# 1017    28990
# 1018    19990
# 1019    24990
# Name: price, Length: 1020, dtype: int64

# %%
df1[df1['price']== 99]
# Out:
#                  model  price  rating                  sim  \
# 608  Namotel Achhe Din     99     NaN  Dual Sim, 3G, Wi-Fi
#
#                   processor               ram  \
# 608  1 GB RAM, 4 GB inbuilt  1325 mAh Battery
#
#                              battery                          display  \
# 608  4 inches, 720 x 1280 px Display  2 MP Rear & 0.3 MP Front Camera
#
#                       camera       card   os
# 608  Android v5.0 (Lollipop)  Bluetooth  NaN

# %%
df1['processor']
# Out:
# 0       Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1          Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2             Exynos 1330, Octa Core, 2.4 GHz Processor
# 3         Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4          Dimensity 1080, Octa Core, 2.6 GHz Processor
#                              ...
# 1015      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016     Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017      Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018       Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                                Octa Core Processor
# Name: processor, Length: 1020, dtype: object

# %%
df1.head()
# Out:
#                        model  price  rating  \
# 0              OnePlus 11 5G  54999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      Samsung Galaxy A14 5G  16499    75.0
# 3       Motorola Moto G62 5G  14999    81.0
# 4         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
processor_rows = [640, 645, 647, 657, 665, 699, 748, 757, 817, 857, 881, 882, 917, 925, 927, 930, 1000]
memory_rows = [439, 483, 532, 551, 582, 608, 611, 640, 645, 647, 657, 665, 699, 748, 757, 817, 857, 882, 917, 925, 927, 930, 988, 1000]
battery_rows = [111, 149, 307, 363, 376, 439, 448, 551, 582, 608, 611, 628, 640, 645, 647, 657, 665, 699, 748, 754, 757, 762, 817, 853, 857, 882, 913, 914, 925, 927, 930, 988, 1000]
display_rows = [376, 439, 448, 551, 582, 608, 611, 628, 640, 645, 647, 657, 665, 699, 748, 757, 762, 817, 857, 882, 913, 914, 925, 927, 930, 988, 1000]
camera_rows = [98, 111, 149, 155, 159, 236, 271, 306, 307, 321, 322, 363, 365, 376, 392, 439, 448, 482, 504, 532, 551, 569, 570, 573, 582, 608, 611, 613, 628, 640, 645, 647, 657, 665, 682, 685, 703, 709, 721, 726, 748, 754, 757, 762, 790, 817, 844, 852, 853, 856, 881, 882, 894, 913, 914, 925, 927, 930, 943, 954, 988, 993, 1000, 1014]

# %%
# Convert lists to sets
processor_set = set((processor_rows))
memory_set = set((memory_rows))
battery_set = set((battery_rows))
display_set = set((display_rows))
camera_set = set((camera_rows))

# %%
# Filter the DataFrame using the combined set
df1[df1.index.isin(processor_set | memory_set | battery_set | display_set | camera_set)]
# Out:
#                                   model   price  rating  \
# 98                       Vivo X Fold 5G  106990     NaN
# 111                     Apple iPhone 12   51999    74.0
# 149                Apple iPhone 12 Mini   40999    74.0
# 155                     Nokia 2780 Flip    4990     NaN
# 159                     Oppo Find N2 5G   94990     NaN
# ...                                 ...     ...     ...
# 954   Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988                 Nokia 5310 Dual Sim    3399     NaN
# 993                       Huawei Mate X  169000     NaN
# 1000                    XTouch F40 Flip    1999     NaN
# 1014                      Vivo X Fold 2  119990     NaN
#
#                                                       sim  \
# 98                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1[df1.index.isin(processor_set & memory_set & battery_set & display_set & camera_set)]
# Out:
#                        model  price  rating                             sim  \
# 640           Nokia 105 Plus   1299     NaN                        Dual Sim
# 645          Nokia 2760 Flip   5490     NaN         Dual Sim, 3G, 4G, Wi-Fi
# 647        Motorola Moto A10   1339     NaN                        Dual Sim
# 657            Zanco Tiny T1   2799     NaN                      Single Sim
# 665             itel it2163S    958     NaN                        Dual Sim
# 748             Nokia 400 4G   3290     NaN      Dual Sim, 4G, VoLTE, Wi-Fi
# 757             Karbonn KU3i    995     NaN                        Dual Sim
# 817             itel Magic X   2239     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 882   Nokia 5710 XpressAudio   4799     NaN                Dual Sim, 3G, 4G
# 925            Nokia 3310 4G   3999     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 927       Samsung Guru E1200   1685     NaN                      Single Sim
# ...

# %% [markdown]
# ## `smartphone which are cheap have messy data`

# %%
df1[df1.index.isin(processor_set & memory_set & battery_set & display_set & camera_set)]['price'].mean()
# Out:
# 2537.6923076923076

# %%
df1=df1[df1['price']>=3400]

# %%
df1.head()
# Out:
#                        model  price  rating  \
# 0              OnePlus 11 5G  54999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      Samsung Galaxy A14 5G  16499    75.0
# 3       Motorola Moto G62 5G  14999    81.0
# 4         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
df1[df1.index.isin(processor_set & memory_set & battery_set & display_set & camera_set)]
# Out:
#                       model  price  rating                             sim  \
# 645         Nokia 2760 Flip   5490     NaN         Dual Sim, 3G, 4G, Wi-Fi
# 882  Nokia 5710 XpressAudio   4799     NaN                Dual Sim, 3G, 4G
# 925           Nokia 3310 4G   3999     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                       processor                               ram  \
# 645            1450 mAh Battery  3.6 inches, 240 x 320 px Display
# 882                     No Wifi                       Unisoc T107
# 925  256 MB RAM, 512 MB inbuilt                  1200 mAh Battery
#
#                               battery                            display  \
# 645     5 MP Rear & 5 MP Front Camera  Memory Card Supported, upto 32 GB
# 882         48 MB RAM, 128 MB inbuilt                   1450 mAh Battery
# 925  2.4 inches, 240 x 320 px Display                   2 MP Rear Camera
#
#                                 camera                card  \
# ...

# %%
df1[df1.index.isin(processor_set)]
# Out:
#                       model  price  rating                             sim  \
# 645         Nokia 2760 Flip   5490     NaN         Dual Sim, 3G, 4G, Wi-Fi
# 857             LG Folder 2  11999     NaN       Single Sim, 3G, 4G, Wi-Fi
# 882  Nokia 5710 XpressAudio   4799     NaN                Dual Sim, 3G, 4G
# 925           Nokia 3310 4G   3999     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                       processor                               ram  \
# 645            1450 mAh Battery  3.6 inches, 240 x 320 px Display
# 857      1 GB RAM, 8 GB inbuilt                  1470 mAh Battery
# 882                     No Wifi                       Unisoc T107
# 925  256 MB RAM, 512 MB inbuilt                  1200 mAh Battery
#
#                               battery                            display  \
# 645     5 MP Rear & 5 MP Front Camera  Memory Card Supported, upto 32 GB
# 857  2.8 inches, 240 x 320 px Display                   2 MP Rear Camera
# ...

# %%
df1.drop([645,857,882,925],inplace=True)

# %%
df1[df1.index.isin(memory_set)]
# Out:
#                                 model   price  rating  \
# 439            Apple iPhone SE 3 2022   43900     NaN
# 483  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
#                                          display  \
# ...

# %%
df1.drop([582],inplace=True)

# %%
temp_df=df1[df1.index.isin(battery_set)]
temp_df
# Out:
#                             model   price  rating  \
# 111               Apple iPhone 12   51999    74.0
# 149          Apple iPhone 12 Mini   40999    74.0
# 307       Apple iPhone 12 (128GB)   55999    75.0
# 363  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376               Nokia 2660 Flip    4649     NaN
# 439        Apple iPhone SE 3 2022   43900     NaN
# 448           Apple iPhone 15 Pro  130990    75.0
# 628   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    Apple iPod Touch (7th Gen)   18900     NaN
# 762             Apple iPhone SE 4   49990    60.0
# 853   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# df1.drop([376,754],inplace=True)

# %%
x=temp_df.iloc[:,6:].shift(1,axis=1).values

# %%
df1.loc[temp_df.index,temp_df.columns[6:]]=x

# %%
df1[df1.index.isin(battery_set)]
# Out:
#                             model   price  rating  \
# 111               Apple iPhone 12   51999    74.0
# 149          Apple iPhone 12 Mini   40999    74.0
# 307       Apple iPhone 12 (128GB)   55999    75.0
# 363  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376               Nokia 2660 Flip    4649     NaN
# 439        Apple iPhone SE 3 2022   43900     NaN
# 448           Apple iPhone 15 Pro  130990    75.0
# 628   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    Apple iPod Touch (7th Gen)   18900     NaN
# 762             Apple iPhone SE 4   49990    60.0
# 853   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1[df1.index.isin(display_set)]
# Out:
#                             model   price  rating  \
# 376               Nokia 2660 Flip    4649     NaN
# 439        Apple iPhone SE 3 2022   43900     NaN
# 448           Apple iPhone 15 Pro  130990    75.0
# 628   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762             Apple iPhone SE 4   49990    60.0
# 913  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 376                         Dual Sim, 3G, 4G
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 376                                     No Wifi               Unisoc T107
# ...

# %%
df1[df1.index.isin(camera_set)]
# Out:
#                                          model   price  rating  \
# 98                              Vivo X Fold 5G  106990     NaN
# 111                            Apple iPhone 12   51999    74.0
# 149                       Apple iPhone 12 Mini   40999    74.0
# 155                            Nokia 2780 Flip    4990     NaN
# 159                            Oppo Find N2 5G   94990     NaN
# 236                       Xiaomi Mix Fold 2 5G  106990     NaN
# 271                          Nokia 2720 V Flip    6199     NaN
# 306                    Samsung Galaxy Z Flip 3   69999    84.0
# 307                    Apple iPhone 12 (128GB)   55999    75.0
# 321                    Samsung Galaxy Z Fold 4  154998     NaN
# 322                           Royole FlexPai 2  109999    87.0
# 363               Apple iPhone 12 Mini (128GB)   45999    75.0
# 365                           OPPO Find N Flip   89990    88.0
# 376                            Nokia 2660 Flip    4649     NaN
# ...

# %%
df1.drop([155,271],inplace=True)

# %%
temp_df=df1[df1.index.isin(camera_set)]

# %%
temp_df=temp_df[~temp_df['camera'].str.contains('MP')]

# %%
df1.loc[temp_df.index,'camera']=temp_df['card'].values

# %%
df1[df1.index.isin(camera_set)]
# Out:
#                                          model   price  rating  \
# 98                              Vivo X Fold 5G  106990     NaN
# 111                            Apple iPhone 12   51999    74.0
# 149                       Apple iPhone 12 Mini   40999    74.0
# 159                            Oppo Find N2 5G   94990     NaN
# 236                       Xiaomi Mix Fold 2 5G  106990     NaN
# 306                    Samsung Galaxy Z Flip 3   69999    84.0
# 307                    Apple iPhone 12 (128GB)   55999    75.0
# 321                    Samsung Galaxy Z Fold 4  154998     NaN
# 322                           Royole FlexPai 2  109999    87.0
# 363               Apple iPhone 12 Mini (128GB)   45999    75.0
# 365                           OPPO Find N Flip   89990    88.0
# 376                            Nokia 2660 Flip    4649     NaN
# 392                          OPPO Find N2 Flip   70990    88.0
# 439                     Apple iPhone SE 3 2022   43900     NaN
# ...

# %%
df1['card'].value_counts(dropna=False)
# Out:
# card
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Android v10                                                             11
# ...

# %%
df1['card'].replace('None', np.nan, inplace=True)

# %%
temp_df=df1[df1['card'].str.contains('No FM Radio|HarmonyOS|Android|iOS|Display', na=False)]

# %%
x=temp_df.iloc[:,9:].shift(1,axis=1).values

# %%
df1.loc[temp_df.index,temp_df.columns[9:]]=x

# %%
df1[df1['card'].str.contains('No FM Radio|HarmonyOS|Android|iOS|Display', na=False)]
# Out:
# Empty DataFrame
# Columns: [model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %%
df1.loc[df1['card'].str.contains('MP', na=False), 'card'] = np.nan

# %%
df1[df1['card'].str.contains('MP',na=False)]
# Out:
# Empty DataFrame
# Columns: [model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %%
df1['os'].value_counts(dropna=False)
# Out:
# os
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# Memory Card Supported, upto 256 GB      2
# EMUI v12                                2
# ...

# %%
temp_df=df1[df1['os'].str.contains('Memory Card', na=False)]

# %%
x=temp_df.iloc[:,9:].shift(-1,axis=1).values

# %%
df1.loc[temp_df.index,temp_df.columns[9:]]=x

# %%
df1.head()
# Out:
#                        model  price  rating  \
# 0              OnePlus 11 5G  54999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      Samsung Galaxy A14 5G  16499    75.0
# 3       Motorola Moto G62 5G  14999    81.0
# 4         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
df1.loc[df1['os'].str.contains('FM|Bluetooth|Display', na=False),'os']=np.nan

# %%
df1.isna().sum()
# Out:
# model          0
# price          0
# rating       105
# sim            0
# processor      0
# ram            0
# battery       13
# display        0
# camera         0
# card         227
# os            17
# dtype: int64

# %%
df1[df1['card'].isna()]
# Out:
#                             model   price  rating  \
# 8                 Nothing Phone 1   26749    85.0
# 9              OnePlus Nord 2T 5G   28999    84.0
# 12    Xiaomi Redmi Note 12 Pro 5G   24762    79.0
# 17           OPPO Reno 9 Pro Plus   45999    86.0
# 18                 OnePlus 10R 5G   32999    86.0
# ...                           ...     ...     ...
# 1011                 Oppo Find X6   69990    89.0
# 1012                    itel A23s    4787     NaN
# 1013           Google Pixel 8 Pro   70990    80.0
# 1014                Vivo X Fold 2  119990     NaN
# 1015   Motorola Moto Edge S30 Pro   34990    83.0
#
#                                                  sim  \
# 8            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1[df1['os'].isna()]
# Out:
#                           model   price  rating  \
# 159             Oppo Find N2 5G   94990     NaN
# 306     Samsung Galaxy Z Flip 3   69999    84.0
# 322            Royole FlexPai 2  109999    87.0
# 365            OPPO Find N Flip   89990    88.0
# 376             Nokia 2660 Flip    4649     NaN
# 392           OPPO Find N2 Flip   70990    88.0
# 486               Nokia 8000 4G    6899     NaN
# 504  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570                  LG Wing 5G   54999    89.0
# 613                Oukitel WP21   22990    82.0
# 682                LG V60 ThinQ   79990     NaN
# 721  Asus ROG Phone 6D Ultimate  107990     NaN
# 726            Huawei Mate Xs 2  162990    89.0
# 754  Apple iPod Touch (7th Gen)   18900     NaN
# 844                CAT S22 Flip   14999     NaN
# 894         Royole FlexPai 3 5G  149999    87.0
# 993               Huawei Mate X  169000     NaN
#
#                                                      sim  \
# ...

# %%
df1.head()
# Out:
#                        model  price  rating  \
# 0              OnePlus 11 5G  54999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      Samsung Galaxy A14 5G  16499    75.0
# 3       Motorola Moto G62 5G  14999    81.0
# 4         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# ## `Add a column brand_name before model`

# %%
df1['Brand_name']=df1['model'].str.split(' ').str[0]

# %%
df1.insert(0,'Brand_name',df1.pop('Brand_name'))

# %%
df1['Brand_name']=df1['Brand_name'].str.upper()

# %% [markdown]
# ## ` Replace sim column with 3 columns`

# %%
df1['has_5G']=df1['sim'].str.contains('5G').astype('int')

# %%
df1.insert(4,'has_5G',df1.pop('has_5G'))

# %%
df1['has_nfc']=df1['sim'].str.contains('NFC').astype('int')

# %%
df1.insert(5,'has_nfc',df1.pop('has_nfc'))

# %%
df1['has_IR_Blaster']=df1['sim'].str.contains('IR Blaster').astype('int')

# %%
df1.insert(6,'has_IR_Blaster',df1.pop('has_IR_Blaster'))

# %%
df1['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                               317
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      268
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           155
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster                54
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster           52
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                           46
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    46
# Dual Sim, 3G, 4G, Wi-Fi                                        7
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      7
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                  7
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster                5
# Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                          4
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                       3
# Single Sim, 3G, 4G, VoLTE, Wi-Fi                               3
# ...

# %% [markdown]
# ## ` Split processor into processor name, cores, and CPU speed `

# %%
df1['processor_name']=df1['processor'].str.split(' ').str.get(0)

# %%
df1.insert(7,'processor_name',df1.pop('processor_name'))

# %%
df1['Core']=df1['processor'].str.split(',').str.get(1)

# %%
df1.insert(8,'Core',df1.pop('Core'))

# %%
df1['processor_frequency']=df1['processor'].str.split(',').str.get(2)

# %%
df1.insert(8,'processor_frequency',df1.pop('processor_frequency'))

# %%
df1['processor_name']=df1['processor_name'].str.strip()

# %%
pd.set_option('display.max_columns',None)
df1.head()
# Out:
#   Brand_name                      model  price  rating  has_5G  has_nfc  \
# 0    ONEPLUS              OnePlus 11 5G  54999    89.0       1        1
# 1    ONEPLUS  OnePlus Nord CE 2 Lite 5G  19989    81.0       1        0
# 2    SAMSUNG      Samsung Galaxy A14 5G  16499    75.0       1        0
# 3   MOTOROLA       Motorola Moto G62 5G  14999    81.0       1        0
# 4     REALME         Realme 10 Pro Plus  24999    82.0       1        0
#
#    has_IR_Blaster processor_name processor_frequency        Core  \
# 0               0     Snapdragon   3.2 GHz Processor   Octa Core
# 1               0     Snapdragon   2.2 GHz Processor   Octa Core
# 2               0         Exynos   2.4 GHz Processor   Octa Core
# 3               0     Snapdragon   2.2 GHz Processor   Octa Core
# 4               0      Dimensity   2.6 GHz Processor   Octa Core
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %% [markdown]
# ## `split ram  into 2 columns: RAM and ROM columns`

# %%
df1['RAM']=df1['ram'].str.split(',').str.get(0)

# %%
df1.insert(11,'RAM',df1.pop('RAM'))

# %%
df1['ROM']=df1['ram'].str.split(',').str.get(1)

# %%
df1.insert(12,'ROM',df1.pop('ROM'))

# %% [markdown]
# ## `split battery into  capacity and fast_charging_available`

# %%
df1['battery_capacity']=df1['battery'].str.split(' ').str.get(0)

# %%
df1.insert(14,'battery_capacity',df1.pop('battery_capacity'))

# %%
df1['fast_charging_available']=df1['battery'].str.contains('Fast Charging',na=False).astype(int)

# %%
df1.insert(15,'fast_charging_available',df1.pop('fast_charging_available'))

# %% [markdown]
# ## ` Display split into size, resolution_width, resolution_height, and frequency

# %%
df1['display_size']=df1['display'].str.split(',').str.get(0)

# %%
df1.insert(17,'display_size',df1.pop('display_size'))

# %%
df1['display_width']=df1['display'].str.split(' ').str.get(2).str.split('x').str.get(0).str.strip()

# %%
df1.insert(18,'display_width',df1.pop('display_width'))

# %%
df1['display_height']=df1['display'].str.split(',').str.get(1).str.split('x').str.get(1).str.split('p').str.get(0)

# %%
df1.insert(19,'display_height',df1.pop('display_height'))

# %%
pd.set_option('display.max_colwidth',None)

# %%
df1['Display_Frequency']=df1['display'].str.strip().str.split(',').str.get(2).str.findall(r'\d{2,3}').str.get(0).apply(lambda x: 60 if pd.isna(x) else x).astype(int)

# %%
df1.insert(20,'Display_Frequency',df1.pop('Display_Frequency'))

# %%
df1.head()
# Out:
#   Brand_name                      model  price  rating  has_5G  has_nfc  \
# 0    ONEPLUS              OnePlus 11 5G  54999    89.0       1        1
# 1    ONEPLUS  OnePlus Nord CE 2 Lite 5G  19989    81.0       1        0
# 2    SAMSUNG      Samsung Galaxy A14 5G  16499    75.0       1        0
# 3   MOTOROLA       Motorola Moto G62 5G  14999    81.0       1        0
# 4     REALME         Realme 10 Pro Plus  24999    82.0       1        0
#
#    has_IR_Blaster processor_name processor_frequency        Core  \
# 0               0     Snapdragon   3.2 GHz Processor   Octa Core
# 1               0     Snapdragon   2.2 GHz Processor   Octa Core
# 2               0         Exynos   2.4 GHz Processor   Octa Core
# 3               0     Snapdragon   2.2 GHz Processor   Octa Core
# 4               0      Dimensity   2.6 GHz Processor   Octa Core
#
#                                        sim        RAM              ROM  \
# ...

# %% [markdown]
# ## `split camera into front and rear camera`

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  40
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  38
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  34
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                            23
# 13 MP Rear & 5 MP Front Camera                                        20
#                                                                       ..
# 64 MP + 13 MP + 5 MP Triple Rear & 24 MP Front Camera                  1
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera     1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                  1
# 48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera            1
# Name: count, Length: 287, dtype: int64

# %%
def camera_extractor(text):
  if 'Quad' in text:
    return 4
  elif 'Triple' in text:
    return 3
  elif 'Dual' in text:
    return 2
  else:
    return 1

# %%
df1['Number_of_rear_camera']=df1['camera'].str.split('&').str.get(0).apply(camera_extractor)

# %%
df1.insert(21,'Number_of_rear_camera',df1.pop('Number_of_rear_camera'))

# %%
df1.head()
# Out:
#   Brand_name                      model  price  rating  has_5G  has_nfc  \
# 0    ONEPLUS              OnePlus 11 5G  54999    89.0       1        1
# 1    ONEPLUS  OnePlus Nord CE 2 Lite 5G  19989    81.0       1        0
# 2    SAMSUNG      Samsung Galaxy A14 5G  16499    75.0       1        0
# 3   MOTOROLA       Motorola Moto G62 5G  14999    81.0       1        0
# 4     REALME         Realme 10 Pro Plus  24999    82.0       1        0
#
#    has_IR_Blaster processor_name processor_frequency        Core  \
# 0               0     Snapdragon   3.2 GHz Processor   Octa Core
# 1               0     Snapdragon   2.2 GHz Processor   Octa Core
# 2               0         Exynos   2.4 GHz Processor   Octa Core
# 3               0     Snapdragon   2.2 GHz Processor   Octa Core
# 4               0      Dimensity   2.6 GHz Processor   Octa Core
#
#                                        sim        RAM              ROM  \
# ...

# %%
def cameraextractor(text):
    if pd.isna(text):  # Check if the value is NaN
        return None  # Or any other placeholder you want to use
    if 'Dual' in text:
        return 2
    else:
        return 1

# %%
df1['Number_of_front_camera']=df1['camera'].str.split('&').str.get(1).apply(cameraextractor)

# %%
df1.insert(22,'Number_of_front_camera',df1.pop('Number_of_front_camera'))

# %% [markdown]
# ## `Card split into supported and extended_upto`

# %%
df1['card'].value_counts(dropna=False)
# Out:
# card
# None                                   215
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              129
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      89
# Memory Card (Hybrid)                    31
# Memory Card (Hybrid), upto 256 GB       15
# NaN                                     12
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       7
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 2 TB          3
# Memory Card Supported, upto 1000 GB      1
# Name: count, dtype: int64

# %%
def memmory_card(text):
  if pd.isna(text):
    return None
  elif  'Not' in text:
    return 0
  else:
    return 1

# %%
df1['card_supported'] = df1['card'].str.split(',').str.get(0).apply(memmory_card)

# %%
df1['extended_upto']=df1['card'].str.split(' ').str.get(4)

# %%
df1.head()
# Out:
#   Brand_name                      model  price  rating  has_5G  has_nfc  \
# 0    ONEPLUS              OnePlus 11 5G  54999    89.0       1        1
# 1    ONEPLUS  OnePlus Nord CE 2 Lite 5G  19989    81.0       1        0
# 2    SAMSUNG      Samsung Galaxy A14 5G  16499    75.0       1        0
# 3   MOTOROLA       Motorola Moto G62 5G  14999    81.0       1        0
# 4     REALME         Realme 10 Pro Plus  24999    82.0       1        0
#
#    has_IR_Blaster processor_name processor_frequency        Core  \
# 0               0     Snapdragon   3.2 GHz Processor   Octa Core
# 1               0     Snapdragon   2.2 GHz Processor   Octa Core
# 2               0         Exynos   2.4 GHz Processor   Octa Core
# 3               0     Snapdragon   2.2 GHz Processor   Octa Core
# 4               0      Dimensity   2.6 GHz Processor   Octa Core
#
#                                        sim        RAM              ROM  \
# ...

# %%
n_columns = len(df1.columns)
df1.insert(n_columns-2,'card_supported',df1.pop('card_supported'))

# %%
n_columns = len(df1.columns)
df1.insert(n_columns-1,'extended_upto',df1.pop('extended_upto'))

# %%
df1['os'].unique()
# Out:
# array(['Android v13', 'Android v12', 'iOS v16', 'iOS v15', 'Android v11',
#        'Android v10', 'iOS v13', 'HarmonyOS v2', 'iOS v15.0', 'iOS v14',
#        'Android v10.0', 'Android v8.1 (Oreo)', None, 'iOS v13.0',
#        'Android v11.0', 'Android v9.0 (Pie)', 'Android v12.1',
#        'iOS v12.3', nan, 'iOS v17', 'Android v4.4.2 (KitKat)',
#        'Android v5.1 (Lollipop)', 'Android v5.1.1 (Lollipop)',
#        'Hongmeng OS v3.0', 'Android v8.0 (Oreo)',
#        'Pragati OS (Powered by Android)', 'iOS v10', 'RTOS (Series 30+)',
#        'iOS v14.0', 'Harmony v2.0', 'Hongmeng OS v4.0', 'HarmonyOS v2.0',
#        'Android v6.0 (Marshmallow)', 'EMUI v12', 'HarmonyOS',
#        'Android v7.1 (Nougat)', 'Android', 'Android v9 (Pie)'],
#       dtype=object)

# %%
df1['os'].value_counts(dropna=False)
# Out:
# os
# Android v12                        394
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# None                                14
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# Android v8.0 (Oreo)                  4
# Android v11.0                        4
# iOS v13                              4
# iOS v15.0                            3
# NaN                                  3
# EMUI v12                             2
# HarmonyOS v2.0                       2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# Harmony v2.0                         2
# Android v12.1                        2
# iOS v14.0                            2
# HarmonyOS                            1
# ...

# %%
df1['os'].isna().sum()
# Out:
# 17

# %%
df1['os'].fillna('Unknown', inplace=True)

# %%
df1['os'] = df1['os'].replace({
    'Android': 'Unknown',
    'RTOS (Series 30+)': 'Unknown',
})
df1['os'] = df1['os'].replace({
    'Android v10': 'Android v10.0',
    'Android v11': 'Android v11.0',
    'iOS v15.0': 'iOS v15',
    # Add more corrections as needed
})

# %%
df1['os'].unique()
# Out:
# array(['Android v13', 'Android v12', 'iOS v16', 'iOS v15',
#        'Android v11.0', 'Android v10.0', 'iOS v13', 'HarmonyOS v2',
#        'iOS v14', 'Android v8.1 (Oreo)', 'Unknown', 'iOS v13.0',
#        'Android v9.0 (Pie)', 'Android v12.1', 'iOS v12.3', 'iOS v17',
#        'Android v4.4.2 (KitKat)', 'Android v5.1 (Lollipop)',
#        'Android v5.1.1 (Lollipop)', 'Hongmeng OS v3.0',
#        'Android v8.0 (Oreo)', 'Pragati OS (Powered by Android)',
#        'iOS v10', 'iOS v14.0', 'Harmony v2.0', 'Hongmeng OS v4.0',
#        'HarmonyOS v2.0', 'Android v6.0 (Marshmallow)', 'EMUI v12',
#        'HarmonyOS', 'Android v7.1 (Nougat)', 'Android v9 (Pie)'],
#       dtype=object)

# %%
df1[['os_name', 'os_version']] = df1['os'].str.split(' ', n=1, expand=True)

# %%
n_columns = len(df1.columns)
df1.insert(n_columns-1,'os_name',df1.pop('os_name'))

# %%
n_columns = len(df1.columns)
df1.insert(n_columns-1,'os_version',df1.pop('os_version'))

# %%
df1.head()
# Out:
#   Brand_name                      model  price  rating  has_5G  has_nfc  \
# 0    ONEPLUS              OnePlus 11 5G  54999    89.0       1        1
# 1    ONEPLUS  OnePlus Nord CE 2 Lite 5G  19989    81.0       1        0
# 2    SAMSUNG      Samsung Galaxy A14 5G  16499    75.0       1        0
# 3   MOTOROLA       Motorola Moto G62 5G  14999    81.0       1        0
# 4     REALME         Realme 10 Pro Plus  24999    82.0       1        0
#
#    has_IR_Blaster processor_name processor_frequency        Core  \
# 0               0     Snapdragon   3.2 GHz Processor   Octa Core
# 1               0     Snapdragon   2.2 GHz Processor   Octa Core
# 2               0         Exynos   2.4 GHz Processor   Octa Core
# 3               0     Snapdragon   2.2 GHz Processor   Octa Core
# 4               0      Dimensity   2.6 GHz Processor   Octa Core
#
#                                        sim        RAM              ROM  \
# ...

# %%
df1.columns
# Out:
# Index(['Brand_name', 'model', 'price', 'rating', 'has_5G', 'has_nfc',
#        'has_IR_Blaster', 'processor_name', 'processor_frequency', 'Core',
#        'sim', 'RAM', 'ROM', 'processor', 'battery_capacity',
#        'fast_charging_available', 'ram', 'display_size', 'display_width',
#        'display_height', 'Display_Frequency', 'Number_of_rear_camera',
#        'Number_of_front_camera', 'battery', 'display', 'camera', 'card', 'os',
#        'card_supported', 'extended_upto', 'os_name', 'os_version'],
#       dtype='object')

# %%
# Drop the specified columns
columns_to_drop = ['sim', 'processor', 'ram', 'battery', 'display', 'camera', 'card', 'os']
df1.drop(columns=columns_to_drop, inplace=True)

# %%
df1.head()
# Out:
#   Brand_name                      model  price  rating  has_5G  has_nfc  \
# 0    ONEPLUS              OnePlus 11 5G  54999    89.0       1        1
# 1    ONEPLUS  OnePlus Nord CE 2 Lite 5G  19989    81.0       1        0
# 2    SAMSUNG      Samsung Galaxy A14 5G  16499    75.0       1        0
# 3   MOTOROLA       Motorola Moto G62 5G  14999    81.0       1        0
# 4     REALME         Realme 10 Pro Plus  24999    82.0       1        0
#
#    has_IR_Blaster processor_name processor_frequency        Core        RAM  \
# 0               0     Snapdragon   3.2 GHz Processor   Octa Core  12 GB RAM
# 1               0     Snapdragon   2.2 GHz Processor   Octa Core   6 GB RAM
# 2               0         Exynos   2.4 GHz Processor   Octa Core   4 GB RAM
# 3               0     Snapdragon   2.2 GHz Processor   Octa Core   6 GB RAM
# 4               0      Dimensity   2.6 GHz Processor   Octa Core   6 GB RAM
#
# ...

# %%
df1['extended_upto'] = df1['extended_upto'].fillna(0)

# %%
df1['card_supported'] = df1['card_supported'].fillna(0)

# %%
df1['processor_frequency'] = df1['processor_frequency'].fillna('Unknown')

# %%
mode_value = df1['Number_of_front_camera'].mode()[0]
df1['Number_of_front_camera'].fillna(mode_value, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 984 entries, 0 to 1019
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Brand_name               984 non-null    object
#  1   model                    984 non-null    object
#  2   price                    984 non-null    int64
#  3   rating                   984 non-null    float64
#  4   has_5G                   984 non-null    int64
#  5   has_nfc                  984 non-null    int64
#  6   has_IR_Blaster           984 non-null    int64
#  7   processor_name           984 non-null    int64
#  8   processor_frequency      984 non-null    object
#  9   Core                     984 non-null    int64
#  10  RAM                      984 non-null    int64
#  11  ROM                      984 non-null    int64
#  12  battery_capacity         984 non-null    int64
#  13  fast_charging_available  984 non-null    int64
# ...

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

columns_to_use = ['price', 'has_5G', 'has_nfc', 'has_IR_Blaster', 'fast_charging_available', 'Display_Frequency', 'Number_of_rear_camera', 'Number_of_front_camera', 'card_supported']

le = LabelEncoder()

categorical_columns = ['processor_name', 'Core', 'RAM', 'ROM', 'battery_capacity', 'display_size', 'display_width', 'display_height', 'extended_upto', 'os_name', 'os_version']

for col in categorical_columns:
    if col in df1.columns:
        df1[col] = le.fit_transform(df1[col].astype(str))

columns_to_use.append('rating')

knn_data = df1[columns_to_use]

imputer = KNNImputer(n_neighbors=5)

df1_imputed = imputer.fit_transform(knn_data)

df1['rating'] = df1_imputed[:, columns_to_use.index('rating')]

# %%
df1.isna().sum()
# Out:
# Brand_name                 0
# model                      0
# price                      0
# rating                     0
# has_5G                     0
# has_nfc                    0
# has_IR_Blaster             0
# processor_name             0
# processor_frequency        0
# Core                       0
# RAM                        0
# ROM                        0
# battery_capacity           0
# fast_charging_available    0
# display_size               0
# display_width              0
# display_height             0
# Display_Frequency          0
# Number_of_rear_camera      0
# Number_of_front_camera     0
# card_supported             0
# extended_upto              0
# os_name                    0
# os_version                 0
# dtype: int64

# %%
df1.to_csv('smartphone_cleaned_v2.csv',index=False)
